# %% [markdown]
# # NLP for Stock Market Prediction
# Author: Antonio Stark, Sasha Pukhova, Frank Looi, Precious Enharo
#
# Kaggle challenge: https://www.kaggle.com/aaron7sun/stocknews
# Kaggle article: https://www.kaggle.com/rahulvarma9595/nlp-for-stock-market-predictions

# %% [markdown]
# ## Import packages and libraries

# %%
# import packages
import pandas as pd
import numpy as np
import string
import time
import gensim

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec, KeyedVectors
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ## Import data

# %%
# import data
data = pd.read_csv('Combined_News_DJIA.csv')

print('data is %d data points with %d features'%(data.shape[0],data.shape[1]))
data.head()
# Out:
# data is 1989 data points with 27 features
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3  2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4  2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# 2  b'"If we had no sexual harassment we would hav...
# 3  b' Israel clears troops who killed Reuters cam...
# 4  b'Swedish wrestler Ara Abrahamian throws away ...
#
#                                                 Top4  \
# 0  b'Russian tanks are moving towards the capital...
# 1  b'Georgian army flees in disarray as Russians ...
# 2  b"Al-Qa'eda is losing support in Iraq because ...
# 3  b'Britain\'s policy of being tough on drugs is...
# 4  b'Russia exaggerated the death toll in South O...
#
#                                                 Top5  \
# 0  b"Afghan children raped with 'impunity,' U.N. ...
# 1      b"Olympic opening ceremony fireworks 'faked'"
# 2  b'Ceasefire in Georgia: Putin Outmaneuvers the...
# 3  b'Body of 14 year old found in trunk; Latest (...
# 4  b'Missile That Killed 9 Inside Pakistan May Ha...
#
#                                                 Top6  \
# 0  b'150 Russian tanks have entered South Ossetia...
# 1  b'What were the Mossad with fraudulent New Zea...
# 2  b'Why Microsoft and Intel tried to kill the XO...
# 3  b'China has moved 10 *million* quake survivors...
# 4  b"Rushdie Condemns Random House's Refusal to P...
#
#                                                 Top7  \
# 0  b"Breaking: Georgia invades South Ossetia, Rus...
# 1  b'Russia angered by Israeli military sale to G...
# 2  b'Stratfor: The Russo-Georgian War and the Bal...
# 3  b"Bush announces Operation Get All Up In Russi...
# 4  b'Poland and US agree to missle defense deal. ...
#
#                                                 Top8  \
# 0  b"The 'enemy combatent' trials are nothing but...
# 1  b'An American citizen living in S.Ossetia blam...
# 2  b"I'm Trying to Get a Sense of This Whole Geor...
# 3             b'Russian forces sink Georgian ships '
# 4  b'Will the Russians conquer Tblisi? Bet on it,...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                Top16  \
# 0  b'Georgia Invades South Ossetia - if Russia ge...
# 1  b'Israel and the US behind the Georgian aggres...
# 2  b'U.S. troops still in Georgia (did you know t...
# 3                      b'Elephants extinct by 2020?'
# 4  b'Bank analyst forecast Georgian crisis 2 days...
#
#                                                Top17  \
# 0                b'Al-Qaeda Faces Islamist Backlash'
# 1  b'"Do not believe TV, neither Russian nor Geor...
# 2       b'Why Russias response to Georgia was right'
# 3  b'US humanitarian missions soon in Georgia - i...
# 4  b"Georgia confict could set back Russia's US r...
#
#                                                Top18  \
# 0  b'Condoleezza Rice: "The US would not act to p...
# 1  b'Riots are still going on in Montreal (Canada...
# 2  b'Gorbachev accuses U.S. of making a "serious ...
# 3             b"Georgia's DDOS came from US sources"
# 4  b'War in the Caucasus is as much the product o...
#
#                                                Top19  \
# 0  b'This is a busy day:  The European Union has ...
# 1    b'China to overtake US as largest manufacturer'
# 2         b'Russia, Georgia, and NATO: Cold War Two'
# 3  b'Russian convoy heads into Georgia, violating...
# 4  b'"Non-media" photos of South Ossetia/Georgia ...
#
#                                                Top20  \
# 0  b"Georgia will withdraw 1,000 soldiers from Ir...
# 1                     b'War in South Ossetia [PICS]'
# 2  b'Remember that adorable 62-year-old who led y...
# 3  b'Israeli defence minister: US against strike ...
# 4  b'Georgian TV reporter shot by Russian sniper ...
#
#                                                Top21  \
# 0  b'Why the Pentagon Thinks Attacking Iran is a ...
# 1  b'Israeli Physicians Group Condemns State Tort...
# 2          b'War in Georgia: The Israeli connection'
# 3                     b'Gorbachev: We Had No Choice'
# 4  b'Saudi Arabia: Mother moves to block child ma...
#
#                                                Top22  \
# 0  b'Caucasus in crisis: Georgia invades South Os...
# 1  b' Russia has just beaten the United States ov...
# 2  b'All signs point to the US encouraging Georgi...
# 3  b'Witness: Russian forces head towards Tbilisi...
# 4   b'Taliban wages war on humanitarian aid workers'
#
#                                                Top23  \
# 0  b'Indian shoe manufactory  - And again in a se...
# 1  b'Perhaps *the* question about the Georgia - R...
# 2  b'Christopher King argues that the US and NATO...
# 3  b' Quarter of Russians blame U.S. for conflict...
# 4  b'Russia: World  "can forget about" Georgia\'s...
#
#                                                Top24  \
# 0  b'Visitors Suffering from Mental Illnesses Ban...
# 1                 b'Russia is so much better at war'
# 2                        b'America: The New Mexico?'
# 3  b'Georgian president  says US military will ta...
# 4  b'Darfur rebels accuse Sudan of mounting major...
#
#                                                Top25
# 0           b"No Help for Mexico's Kidnapping Surge"
# 1  b"So this is what it's come to: trading sex fo...
# 2  b"BBC NEWS | Asia-Pacific | Extinction 'by man...
# 3  b'2006: Nobel laureate Aleksander Solzhenitsyn...
# 4  b'Philippines : Peace Advocate say Muslims nee...
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data preprocessing
# ### Data cleaning & tokenization & normalization

# %%
# data cleaning & tokenization & normalization
## create copy of original dataframe
dataClean = data.copy()

## create set for stopwords as dictionaries are faster
stops = set(stopwords.words('english'))

# news header you want to test
## (2,5) is interesting to see how "Al-Qa'eda" gets transferred
## (4,3) is interesting to see how numbers are encoded
## (2,15) is interesting to see how both numbers ('55') and hyphens ('mega-city') are encoded
## (1988,24) gives a bug for replacing numbers and removing stop words
tester = (2,15)

for i in range(2,data.shape[1]):
    if i==tester[1]:
        print('Original text:')
        print(dataClean.iloc[tester[0],i])
    
    # data cleaning
    ## remove 'b'' at the start and ''' at the end
    dataClean.iloc[:,i]=dataClean.iloc[:,i].str.strip("b'")
    if i==tester[1]:
        print('\nCleaned text:')
        print(dataClean.iloc[tester[0],i])
    
    ## remove punctuation
    dataClean.iloc[:,i]=dataClean.iloc[:,i].str.translate(str.maketrans('', '', string.punctuation))
    if i==tester[1]:
        print('\nPunctuations removed:')
        print(dataClean.iloc[tester[0],i])
        
    # normalization
    ## make lowercase
    dataClean.iloc[:,i]=dataClean.iloc[:,i].str.lower()
    if i==tester[1]:
        print('\nLowercase:')
        print(dataClean.iloc[tester[0],i])
    
    # tokenization
    ## word_tokenize version is below
    dataClean.iloc[:,i]=dataClean.iloc[:,i].str.split()
    if i==tester[1]:
        print('\nTokenized:')
        print(dataClean.iloc[tester[0],i])
        
    # replace numbers
    dataClean.iloc[:,i]=dataClean.iloc[:,i].apply(lambda sent: 'num' if isinstance(sent,float) else ['num' if token.isdigit() else token for token in sent])
    if i==tester[1]:
        print('\nReplaced numbers:')
        print(dataClean.iloc[tester[0],i])
        print()
        
    # remove stop words
    dataClean.iloc[:,i]=dataClean.iloc[:,i].apply(lambda sent: [token for token in sent if token not in stops])
    if i==tester[1]:
        print('\nRemoved stop words:')
        print(dataClean.iloc[tester[0],i])
# Out:
# Original text:
# b'55 pyramids as large as the Luxor stacked into a mega-city pyramid in Tokyo Bay'
#
# Cleaned text:
# 55 pyramids as large as the Luxor stacked into a mega-city pyramid in Tokyo Bay
#
# Punctuations removed:
# 55 pyramids as large as the Luxor stacked into a megacity pyramid in Tokyo Bay
#
# Lowercase:
# 55 pyramids as large as the luxor stacked into a megacity pyramid in tokyo bay
#
# Tokenized:
# ['55', 'pyramids', 'as', 'large', 'as', 'the', 'luxor', 'stacked', 'into', 'a', 'megacity', 'pyramid', 'in', 'tokyo', 'bay']
#
# Replaced numbers:
# ['num', 'pyramids', 'as', 'large', 'as', 'the', 'luxor', 'stacked', 'into', 'a', 'megacity', 'pyramid', 'in', 'tokyo', 'bay']
#
#
# Removed stop words:
# ['num', 'pyramids', 'large', 'luxor', 'stacked', 'megacity', 'pyramid', 'tokyo', 'bay']

# %%
dataClean.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  [georgia, downs, two, russian, warplanes, coun...
# 1  2008-08-11      1  [wont, america, nato, help, us, wont, help, us...
# 2  2008-08-12      0  [remember, adorable, 9yearold, sang, opening, ...
# 3  2008-08-13      0  [us, refuses, israel, weapons, attack, iran, r...
# 4  2008-08-14      1                  [experts, admit, legalise, drugs]
#
#                                                 Top2  \
# 0                   [breaking, musharraf, impeached]
# 1             [bush, puts, foot, georgian, conflict]
# 2                 [russia, ends, georgia, operation]
# 3  [president, ordered, attack, tskhinvali, capit...
# 4  [war, south, osetia, num, pictures, made, russ...
#
#                                                 Top3  \
# 0  [russia, today, columns, troops, roll, south, ...
# 1  [jewish, georgian, minister, thanks, israeli, ...
# 2              [sexual, harassment, would, children]
# 3  [israel, clears, troops, killed, reuters, came...
# 4  [swedish, wrestler, ara, abrahamian, throws, a...
#
#                                                 Top4  \
# 0  [russian, tanks, moving, towards, capital, sou...
# 1  [georgian, army, flees, disarray, russians, ad...
# 2  [alqaeda, losing, support, iraq, brutal, crack...
# 3  [britains, policy, tough, drugs, pointless, sa...
# 4  [russia, exaggerated, death, toll, south, osse...
#
#                                                 Top5  \
# 0  [afghan, children, raped, impunity, un, offici...
# 1     [olympic, opening, ceremony, fireworks, faked]
# 2    [ceasefire, georgia, putin, outmaneuvers, west]
# 3  [body, num, year, old, found, trunk, latest, r...
# 4  [missile, killed, num, inside, pakistan, may, ...
#
#                                                 Top6  \
# 0  [num, russian, tanks, entered, south, ossetia,...
# 1  [mossad, fraudulent, new, zealand, passports, ...
# 2   [microsoft, intel, tried, kill, xo, num, laptop]
# 3  [china, moved, num, million, quake, survivors,...
# 4  [rushdie, condemns, random, houses, refusal, p...
#
#                                                 Top7  \
# 0  [breaking, georgia, invades, south, ossetia, r...
# 1  [russia, angered, israeli, military, sale, geo...
# 2     [stratfor, russogeorgian, war, balance, power]
# 3  [bush, announces, operation, get, russias, gri...
# 4  [poland, us, agree, missle, defense, deal, int...
#
#                                                 Top8  \
# 0  [enemy, combatent, trials, nothing, sham, sali...
# 1  [american, citizen, living, sossetia, blames, ...
# 2  [im, trying, get, sense, whole, georgiarussia,...
# 3           [russian, forces, sink, georgian, ships]
# 4   [russians, conquer, tblisi, bet, seriously, bet]
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                Top16  \
# 0  [georgia, invades, south, ossetia, russia, get...
# 1         [israel, us, behind, georgian, aggression]
# 2  [us, troops, still, georgia, know, georgia, fi...
# 3                          [elephants, extinct, num]
# 4  [bank, analyst, forecast, georgian, crisis, nu...
#
#                                                Top17  \
# 0               [alqaeda, faces, islamist, backlash]
# 1  [believe, tv, neither, russian, georgian, much...
# 2                [russias, response, georgia, right]
# 3  [us, humanitarian, missions, soon, georgia, ru...
# 4  [georgia, confict, could, set, back, russias, ...
#
#                                                Top18  \
# 0  [condoleezza, rice, us, would, act, prevent, i...
# 1  [riots, still, going, montreal, canada, police...
# 2  [gorbachev, accuses, us, making, serious, blun...
# 3                [georgias, ddos, came, us, sources]
# 4  [war, caucasus, much, product, american, imper...
#
#                                                Top19  \
# 0  [busy, day, european, union, approved, new, sa...
# 1       [china, overtake, us, largest, manufacturer]
# 2            [russia, georgia, nato, cold, war, two]
# 3  [russian, convoy, heads, georgia, violating, t...
# 4  [nonmedia, photos, south, ossetiageorgia, conf...
#
#                                                Top20  \
# 0  [georgia, withdraw, num, soldiers, iraq, help,...
# 1                        [war, south, ossetia, pics]
# 2  [remember, adorable, 62yearold, led, country, ...
# 3     [israeli, defence, minister, us, strike, iran]
# 4  [georgian, tv, reporter, shot, russian, sniper...
#
#                                                Top21  \
# 0  [pentagon, thinks, attacking, iran, bad, idea,...
# 1  [israeli, physicians, group, condemns, state, ...
# 2                [war, georgia, israeli, connection]
# 3                                [gorbachev, choice]
# 4  [saudi, arabia, mother, moves, block, child, m...
#
#                                                Top22  \
# 0  [caucasus, crisis, georgia, invades, south, os...
# 1  [russia, beaten, united, states, head, peak, oil]
# 2  [signs, point, us, encouraging, georgia, invad...
# 3  [witness, russian, forces, head, towards, tbil...
# 4  [taliban, wages, war, humanitarian, aid, workers]
#
#                                                Top23  \
# 0    [indian, shoe, manufactory, series, like, work]
# 1     [perhaps, question, georgia, russia, conflict]
# 2  [christopher, king, argues, us, nato, behind, ...
# 3     [quarter, russians, blame, us, conflict, poll]
# 4  [russia, world, forget, georgias, territorial,...
#
#                                                Top24  \
# 0  [visitors, suffering, mental, illnesses, banne...
# 1                        [russia, much, better, war]
# 2                             [america, new, mexico]
# 3  [georgian, president, says, us, military, take...
# 4  [darfur, rebels, accuse, sudan, mounting, majo...
#
#                                                Top25
# 0                 [help, mexicos, kidnapping, surge]
# 1                         [come, trading, sex, food]
# 2  [bbc, news, asiapacific, extinction, man, clim...
# 3  [num, nobel, laureate, aleksander, solzhenitsy...
# 4  [philippines, peace, advocate, say, muslims, n...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Stemming, lemmatization, canonicalization

# %%
# do either stemming or lemmatization
stemming = False # converted philippines to philippin in (4,25)
lemmatization = True # converts to proper words but philippine? (4,25)

dataNormal = dataClean.copy()
tester = (0,5) 
print('Original text:')
print(data.iloc[tester[0],tester[1]])
print('\nCleaned text:')
print(dataClean.iloc[tester[0],tester[1]])

if stemming:
    porter = PorterStemmer()   
    for i in range(2,dataNormal.shape[1]):
        dataNormal.iloc[:,i]=dataNormal.iloc[:,i].apply(lambda x: [porter.stem(y) for y in x])
    print('\nAfter stemming:')
    print(dataNormal.iloc[tester[0],tester[1]])
elif lemmatization:
    lemmatizer = WordNetLemmatizer()
    for i in range(2,data.shape[1]):
        dataNormal.iloc[:,i]=dataNormal.iloc[:,i].apply(lambda x: [lemmatizer.lemmatize(y) for y in x])
    print('\nAfter lemmatization:')
    print(dataNormal.iloc[tester[0],tester[1]])
        
dataNormal.head()
# Out:
# Original text:
# b'Russian tanks are moving towards the capital of South Ossetia, which has reportedly been completely destroyed by Georgian artillery fire'
#
# Cleaned text:
# ['russian', 'tanks', 'moving', 'towards', 'capital', 'south', 'ossetia', 'reportedly', 'completely', 'destroyed', 'georgian', 'artillery', 'fire']
#
# After lemmatization:
# ['russian', 'tank', 'moving', 'towards', 'capital', 'south', 'ossetia', 'reportedly', 'completely', 'destroyed', 'georgian', 'artillery', 'fire']
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  [georgia, down, two, russian, warplane, countr...
# 1  2008-08-11      1  [wont, america, nato, help, u, wont, help, u, ...
# 2  2008-08-12      0  [remember, adorable, 9yearold, sang, opening, ...
# 3  2008-08-13      0  [u, refuse, israel, weapon, attack, iran, report]
# 4  2008-08-14      1                    [expert, admit, legalise, drug]
#
#                                                 Top2  \
# 0                   [breaking, musharraf, impeached]
# 1              [bush, put, foot, georgian, conflict]
# 2                  [russia, end, georgia, operation]
# 3  [president, ordered, attack, tskhinvali, capit...
# 4  [war, south, osetia, num, picture, made, russi...
#
#                                                 Top3  \
# 0  [russia, today, column, troop, roll, south, os...
# 1  [jewish, georgian, minister, thanks, israeli, ...
# 2                 [sexual, harassment, would, child]
# 3  [israel, clear, troop, killed, reuters, camera...
# 4  [swedish, wrestler, ara, abrahamian, throw, aw...
#
#                                                 Top4  \
# 0  [russian, tank, moving, towards, capital, sout...
# 1  [georgian, army, flees, disarray, russian, adv...
# 2  [alqaeda, losing, support, iraq, brutal, crack...
# 3  [britain, policy, tough, drug, pointless, say,...
# 4  [russia, exaggerated, death, toll, south, osse...
#
#                                                 Top5  \
# 0  [afghan, child, raped, impunity, un, official,...
# 1      [olympic, opening, ceremony, firework, faked]
# 2    [ceasefire, georgia, putin, outmaneuvers, west]
# 3  [body, num, year, old, found, trunk, latest, r...
# 4  [missile, killed, num, inside, pakistan, may, ...
#
#                                                 Top6  \
# 0  [num, russian, tank, entered, south, ossetia, ...
# 1  [mossad, fraudulent, new, zealand, passport, i...
# 2   [microsoft, intel, tried, kill, xo, num, laptop]
# 3  [china, moved, num, million, quake, survivor, ...
# 4  [rushdie, condemns, random, house, refusal, pu...
#
#                                                 Top7  \
# 0  [breaking, georgia, invades, south, ossetia, r...
# 1  [russia, angered, israeli, military, sale, geo...
# 2     [stratfor, russogeorgian, war, balance, power]
# 3  [bush, announces, operation, get, russia, gril...
# 4  [poland, u, agree, missle, defense, deal, inte...
#
#                                                 Top8  \
# 0  [enemy, combatent, trial, nothing, sham, salim...
# 1  [american, citizen, living, sossetia, blame, u...
# 2  [im, trying, get, sense, whole, georgiarussia,...
# 3             [russian, force, sink, georgian, ship]
# 4    [russian, conquer, tblisi, bet, seriously, bet]
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                Top16  \
# 0  [georgia, invades, south, ossetia, russia, get...
# 1          [israel, u, behind, georgian, aggression]
# 2  [u, troop, still, georgia, know, georgia, firs...
# 3                           [elephant, extinct, num]
# 4  [bank, analyst, forecast, georgian, crisis, nu...
#
#                                                Top17  \
# 0                [alqaeda, face, islamist, backlash]
# 1  [believe, tv, neither, russian, georgian, much...
# 2                 [russia, response, georgia, right]
# 3  [u, humanitarian, mission, soon, georgia, russ...
# 4  [georgia, confict, could, set, back, russia, u...
#
#                                                Top18  \
# 0  [condoleezza, rice, u, would, act, prevent, is...
# 1  [riot, still, going, montreal, canada, police,...
# 2  [gorbachev, accuses, u, making, serious, blund...
# 3                   [georgia, ddos, came, u, source]
# 4  [war, caucasus, much, product, american, imper...
#
#                                                Top19  \
# 0  [busy, day, european, union, approved, new, sa...
# 1        [china, overtake, u, largest, manufacturer]
# 2            [russia, georgia, nato, cold, war, two]
# 3  [russian, convoy, head, georgia, violating, tr...
# 4  [nonmedia, photo, south, ossetiageorgia, confl...
#
#                                                Top20  \
# 0  [georgia, withdraw, num, soldier, iraq, help, ...
# 1                         [war, south, ossetia, pic]
# 2  [remember, adorable, 62yearold, led, country, ...
# 3      [israeli, defence, minister, u, strike, iran]
# 4  [georgian, tv, reporter, shot, russian, sniper...
#
#                                                Top21  \
# 0  [pentagon, think, attacking, iran, bad, idea, ...
# 1  [israeli, physician, group, condemns, state, t...
# 2                [war, georgia, israeli, connection]
# 3                                [gorbachev, choice]
# 4  [saudi, arabia, mother, move, block, child, ma...
#
#                                                Top22  \
# 0  [caucasus, crisis, georgia, invades, south, os...
# 1   [russia, beaten, united, state, head, peak, oil]
# 2  [sign, point, u, encouraging, georgia, invade,...
# 3  [witness, russian, force, head, towards, tbili...
# 4    [taliban, wage, war, humanitarian, aid, worker]
#
#                                                Top23  \
# 0    [indian, shoe, manufactory, series, like, work]
# 1     [perhaps, question, georgia, russia, conflict]
# 2  [christopher, king, argues, u, nato, behind, g...
# 3       [quarter, russian, blame, u, conflict, poll]
# 4  [russia, world, forget, georgia, territorial, ...
#
#                                                Top24  \
# 0  [visitor, suffering, mental, illness, banned, ...
# 1                        [russia, much, better, war]
# 2                             [america, new, mexico]
# 3  [georgian, president, say, u, military, take, ...
# 4  [darfur, rebel, accuse, sudan, mounting, major...
#
#                                                Top25
# 0                  [help, mexico, kidnapping, surge]
# 1                         [come, trading, sex, food]
# 2  [bbc, news, asiapacific, extinction, man, clim...
# 3  [num, nobel, laureate, aleksander, solzhenitsy...
# 4  [philippine, peace, advocate, say, muslim, nee...
#
# [5 rows x 27 columns]

# %%
dataNormal.tail()
# Out:
#             Date  Label                                               Top1  \
# 1984  2016-06-27      0  [barclays, rb, share, suspended, trading, tank...
# 1985  2016-06-28      1  [num, scientist, australia, want, save, great,...
# 1986  2016-06-29      1                     [explosion, airport, istanbul]
# 1987  2016-06-30      1  [jamaica, proposes, marijuana, dispenser, tour...
# 1988  2016-07-01      1  [117yearold, woman, mexico, city, finally, rec...
#
#                                                    Top2  \
# 1984  [pope, say, church, ask, forgiveness, gay, pas...
# 1985  [personal, detail, num, french, police, office...
# 1986  [yemeni, former, president, terrorism, offspri...
# 1987  [stephen, hawking, say, pollution, stupidity, ...
# 1988  [imf, chief, back, athens, permanent, olympic,...
#
#                                                    Top3  \
# 1984     [poland, shocked, xenophobic, abuse, pole, uk]
# 1985  [sampp, cut, united, kingdom, sovereign, credi...
# 1986  [uk, must, accept, freedom, movement, access, ...
# 1987  [boris, johnson, say, run, tory, party, leader...
# 1988    [president, france, say, brexit, donald, trump]
#
#                                                    Top4  \
# 1984              [second, referendum, cabinet, agrees]
# 1985             [huge, helium, deposit, found, africa]
# 1986  [devastated, scientist, late, captive, breed, ...
# 1987  [six, gay, men, ivory, coast, abused, forced, ...
# 1988  [british, man, must, give, police, num, hour, ...
#
#                                                    Top5  \
# 1984   [scotland, welcome, join, eu, merkel, ally, say]
# 1985  [ceo, south, african, state, broadcaster, quit...
# 1986  [british, labor, party, leader, jeremy, corbyn...
# 1987  [switzerland, denies, citizenship, muslim, imm...
# 1988  [num, nobel, laureate, urge, greenpeace, stop,...
#
#                                                    Top6  \
# 1984  [sterling, dip, friday, 31year, low, amid, bre...
# 1985  [brexit, cost, investor, num, trillion, worst,...
# 1986     [muslim, shop, uk, firebombed, people, inside]
# 1987  [palestinian, terrorist, stab, israeli, teen, ...
# 1988  [brazil, huge, spike, number, police, killing,...
#
#                                                    Top7  \
# 1984  [negative, news, south, african, president, al...
# 1985  [hong, kong, democracy, activist, call, return...
# 1986  [mexican, authority, sexually, torture, woman,...
# 1987  [puerto, rico, default, num, billion, debt, fr...
# 1988  [austria, highest, court, annuls, presidential...
#
#                                                    Top8  \
# 1984  [surge, hate, crime, uk, following, uk, brexit...
# 1985  [brexit, iceland, president, say, uk, join, tr...
# 1986              [uk, share, pound, continue, recover]
# 1987  [republic, ireland, fan, awarded, medal, sport...
# 1988  [facebook, win, privacy, case, track, belgian,...
#
#                             ...                          \
# 1984                        ...
# 1985                        ...
# 1986                        ...
# 1987                        ...
# 1988                        ...
#
#                                                   Top16  \
# 1984  [german, lawyer, probe, erdogan, alleged, war,...
# 1985  [u, canada, mexico, pledge, num, power, clean,...
# 1986  [escape, tunnel, dug, hand, found, holocaust, ...
# 1987  [google, free, wifi, indian, railway, station,...
# 1988  [united, state, placed, myanmar, uzbekistan, s...
#
#                                                   Top17  \
# 1984  [boris, johnson, say, uk, continue, intensify,...
# 1985  [increasing, evidence, australia, torturing, r...
# 1986  [land, beijing, sinking, much, four, inch, per...
# 1987  [mounting, evidence, suggests, hobbit, wiped, ...
# 1988  [sampp, revise, european, union, credit, ratin...
#
#                                                   Top18  \
# 1984  [richard, branson, calling, uk, government, ho...
# 1985  [richard, branson, founder, virgin, group, sai...
# 1986  [car, bomb, antiislamic, attack, mosque, perth...
# 1987  [men, carried, tuesday, terror, attack, istanb...
# 1988  [india, get, num, billion, loan, world, bank, ...
#
#                                                   Top19  \
# 1984             [turkey, sorry, downing, russian, jet]
# 1985  [37000yrold, skull, borneo, reveals, surprise,...
# 1986  [emaciated, lion, taiz, zoo, trapped, bloodsoa...
# 1987  [call, suspend, saudi, arabia, un, human, righ...
# 1988  [u, sailor, detained, iran, spoke, much, inter...
#
#                                                   Top20  \
# 1984  [edward, snowden, lawyer, vow, new, push, pard...
# 1985  [palestinian, stone, western, wall, worshiper,...
# 1986  [rupert, murdoch, describes, brexit, wonderful...
# 1987  [num, nobel, laureate, call, greenpeace, antig...
# 1988  [mass, fish, kill, vietnam, solved, taiwan, st...
#
#                                                   Top21  \
# 1984  [brexit, opinion, poll, reveals, majority, don...
# 1985                [jeanclaude, juncker, asks, farage]
# 1986              [num, killed, yemen, suicide, attack]
# 1987  [british, pedophile, sentenced, num, year, u, ...
# 1988  [philippine, president, rodrigo, duterte, urge...
#
#                                                   Top22  \
# 1984  [conservative, mp, leave, campaigner, leave, c...
# 1985  [romanian, remainians, offering, new, home, nu...
# 1986  [google, found, disastrous, symantec, norton, ...
# 1987  [u, permitted, num, offshore, fracks, gulf, me...
# 1988  [spain, arrest, three, pakistani, accused, pro...
#
#                                                   Top23  \
# 1984  [economist, predict, uk, recession, weakening,...
# 1985      [brexit, gibraltar, talk, scotland, stay, eu]
# 1986  [extremist, violence, rise, germany, domestic,...
# 1987  [swimming, ridicule, french, beach, police, ca...
# 1988  [venezuela, anger, food, shortage, still, moun...
#
#                                                   Top24  \
# 1984  [new, eu, superstate, plan, france, germany, c...
# 1985            [num, suicide, bomber, strike, lebanon]
# 1986  [bbc, news, labour, mp, pas, corbyn, noconfide...
# 1987  [uefa, say, minute, silence, istanbul, victim,...
# 1988  [hindu, temple, worker, killed, three, men, mo...
#
#                                                   Top25
# 1984  [pakistani, cleric, declare, transgender, marr...
# 1985  [mexico, security, force, routinely, use, sexu...
# 1986  [tiny, new, zealand, town, many, job, launch, ...
# 1987  [law, enforcement, source, gun, used, paris, t...
# 1988  [ozone, layer, hole, seems, healing, u, amp, u...
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Convert words to vectors

# %% [markdown]
# ### Combine all header words in each date into a single datapoint (flattening)

# %%
dataVector = dataNormal.iloc[:,0:2].copy()

# combine the words in each date into a single datapoint
combined = dataNormal.iloc[:,2].values.tolist()

for i in range(0,dataNormal.shape[0]):
    for j in range (2,dataNormal.shape[1]):
        combined[i] += dataNormal.iloc[i,j]


dataVector['Combined'] = combined
print('dataVector is %d data points with %d features'%(dataVector.shape[0],dataVector.shape[1]))
dataVector.head()
# Out:
# dataVector is 1989 data points with 3 features
#          Date  Label                                           Combined
# 0  2008-08-08      0  [georgia, down, two, russian, warplane, countr...
# 1  2008-08-11      1  [wont, america, nato, help, u, wont, help, u, ...
# 2  2008-08-12      0  [remember, adorable, 9yearold, sang, opening, ...
# 3  2008-08-13      0  [u, refuse, israel, weapon, attack, iran, repo...
# 4  2008-08-14      1  [expert, admit, legalise, drug, expert, admit,...

# %%
# Swap the order
df = pd.DataFrame.from_dict({'Words':dataVector.Combined,'Date':dataVector.Date, 'Label':dataVector.Label})
df.head()
# Out:
#                                                Words        Date  Label
# 0  [georgia, down, two, russian, warplane, countr...  2008-08-08      0
# 1  [wont, america, nato, help, u, wont, help, u, ...  2008-08-11      1
# 2  [remember, adorable, 9yearold, sang, opening, ...  2008-08-12      0
# 3  [u, refuse, israel, weapon, attack, iran, repo...  2008-08-13      0
# 4  [expert, admit, legalise, drug, expert, admit,...  2008-08-14      1

# %%
# Breaking down all headlines by word
# Reference: (Alexander, 2017)

df.reset_index(inplace=True)
rows = []

_ = df.apply(lambda row: [rows.append([nn, row['Date'], row['Label']]) 
                         for nn in row.Words], axis=1)

df_new = pd.DataFrame(rows, columns=['Words','Date', 'Label'])
df_new.head()
# Out:
#       Words        Date  Label
# 0   georgia  2008-08-08      0
# 1      down  2008-08-08      0
# 2       two  2008-08-08      0
# 3   russian  2008-08-08      0
# 4  warplane  2008-08-08      0

# %%
print('There are %d (nonunique) words in the set'%(df_new.shape[0]))
# Out:
# There are 616245 (nonunique) words in the set

# %% [markdown]
# ### Word2vec vs GloVe model

# %%
# GloVe

model = gensim.models.KeyedVectors.load_word2vec_format("~/Downloads/glove.6B/glove.6B.50d.txt", binary=False)
print('GloVe model (vocabulary) is %d words with %d dimensions'%(model.wv.vectors.shape[0],model.wv.vectors.shape[1]))
# Out:
# GloVe model (vocabulary) is 400000 words with 50 dimensions
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.

# %%
# Word2Vec

num_size = 100        # Word vector dimensionality                    
num_min_count = 5     # Minimum frequency of a word to be included in dictionary                       
num_workers = 4       # Number of threads to run in parallel

start_time = time.time()
w2v_model = Word2Vec(df['Words'], size=num_size, min_count=num_min_count, workers=num_workers)
end_time = time.time()
# model.save('w2v-combined-vector-size100-count5-workers4')

# print resulting matrix size
print('W2V model (vocabulary) is %d words with %d dimensions'%(w2v_model.wv.vectors.shape[0],w2v_model.wv.vectors.shape[1]))
print('training time: %.3f seconds'%(end_time-start_time))
# Out:
# W2V model (vocabulary) is 10404 words with 100 dimensions
# training time: 5.153 seconds

# %% [markdown]
# Glove produces much better word similarity results and makes the positioning of words across a single dimention more sparse than Word2Vec which should make it easier for a model to differentiate between items. Before, most items laid within 0.05 of each other across each dimension.

# %%
w1 = 'war'
topN = 5

w1 = 'war'
w2 = 'peace'
w3 = 'terror'
w4 = 'school'

# %%
# Word-2-Vec

print('Top %d words most similar to \'%s\':'%(topN,w1))
topSimWords_1 = w2v_model.wv.most_similar(positive=[w1],topn=topN)
for i in range(0,len(topSimWords_1)):
    print('   \'%s\': %.4f'%(topSimWords_1[i][0],topSimWords_1[i][1]))
    
print('\nSimilarity between \'%s\' and \'%s\': %.3f'%(w1,w2,w2v_model.wv.similarity(w1=w1,w2=w2)))
print('Similarity between \'%s\' and \'%s\': %.3f'%(w1,w3,w2v_model.wv.similarity(w1=w1,w2=w3)))
print('Similarity between \'%s\' and \'%s\': %.3f'%(w2,w4,w2v_model.wv.similarity(w1=w2,w2=w4)))
# Out:
# Top 5 words most similar to 'war':
#    'humanity': 0.7551
#    'cartel': 0.7549
#    'cold': 0.7165
#    'ii': 0.7153
#    'end': 0.7051
#
# Similarity between 'war' and 'peace': 0.520
# Similarity between 'war' and 'terror': 0.397
# Similarity between 'peace' and 'school': 0.132

# %%
# GloVe

print('Top %d words most similar to \'%s\':'%(topN,w1))
topSimWords = model.wv.most_similar(positive=[w1],topn=topN)
for i in range(0,len(topSimWords)):
    print('   \'%s\': %.4f'%(topSimWords[i][0],topSimWords[i][1]))

# test similarities between words
print('\nSimilarity between \'%s\' and \'%s\': %.3f'%(w1,w2,model.wv.similarity(w1=w1,w2=w2)))
print('Similarity between \'%s\' and \'%s\': %.3f'%(w1,w3,model.wv.similarity(w1=w1,w2=w3)))
print('Similarity between \'%s\' and \'%s\': %.3f'%(w2,w4,model.wv.similarity(w1=w2,w2=w4)))
# Out:
# Top 5 words most similar to 'war':
#    'occupation': 0.8530
#    'invasion': 0.8488
#    'wars': 0.8247
#    'conflict': 0.8188
#    'fighting': 0.8163
#
# Similarity between 'war' and 'peace': 0.644
# Similarity between 'war' and 'terror': 0.660
# Similarity between 'peace' and 'school': 0.328
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   if __name__ == '__main__':
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # Remove the CWD from sys.path while we load stuff.
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Create average vector per each date

# %%
import copy
df = copy.deepcopy(df_new)
words = list(model.wv.vocab.keys())
# Out:
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Getting vectors
not_in_vocab = [] 
df['Vector'] = df.apply(lambda row: np.array(model[row.Words]) if row.Words in words else None, axis=1)

# %%
df.head()
# Out:
#       Words        Date  Label  \
# 0   georgia  2008-08-08      0
# 1      down  2008-08-08      0
# 2       two  2008-08-08      0
# 3   russian  2008-08-08      0
# 4  warplane  2008-08-08      0
#
#                                               Vector
# 0  [-1.3427, 0.4592, 0.19281, 0.71305, -0.5934, 0...
# 1  [-0.1981, -0.70847, 0.85857, -0.48108, 0.51562...
# 2  [0.58289, 0.36258, 0.34065, 0.36416, 0.34337, ...
# 3  [0.19318, 0.88272, 0.40764, -0.15212, 0.030107...
# 4  [0.31237, -1.7611, 1.0351, -0.14, 0.34241, 0.1...

# %%
total = len(df)
nulls = sum(df.Vector.isnull())
print('Total num of words in text: ', total)
print('Num of words found in the dictionary: ', total-nulls)
print('Num of NOT found in the dictionary: ', nulls)
print('Percentage (%) of NOT found in the dictionary: ', round(nulls/total, 4)*100)
# Out:
# Total num of words in text:  616245
# Num of words found in the dictionary:  603423
# Num of NOT found in the dictionary:  12822
# Percentage (%) of NOT found in the dictionary:  2.08

# %%
data = copy.deepcopy(df)
data = data.dropna() # dropping columns with words that were not found

# %%
# Breaking down the vector and making each dimention a separate feature
data = pd.merge(data,data.Vector.apply(pd.Series),right_index=True,left_index=True)
data = data.drop(columns=['Vector'])

# %%
data.head()
# Out:
#       Words        Date  Label        0        1        2        3         4  \
# 0   georgia  2008-08-08      0 -1.34270  0.45920  0.19281  0.71305 -0.593400
# 1      down  2008-08-08      0 -0.19810 -0.70847  0.85857 -0.48108  0.515620
# 2       two  2008-08-08      0  0.58289  0.36258  0.34065  0.36416  0.343370
# 3   russian  2008-08-08      0  0.19318  0.88272  0.40764 -0.15212  0.030107
# 4  warplane  2008-08-08      0  0.31237 -1.76110  1.03510 -0.14000  0.342410
#
#           5         6    ...          40        41       42       43  \
# 0  0.063595 -0.871870    ...    -0.33128  0.242350  0.42535 -1.13290
# 1 -0.289240 -0.643110    ...    -0.47409  0.259160  0.41522  0.15245
# 2  0.793870 -0.936200    ...    -0.54738  0.152440  0.41000  0.15702
# 3  0.061858 -0.022592    ...     0.57779  0.044094  1.87730 -1.40230
# 4  0.132540 -1.227100    ...     0.26021  0.145460  1.30430 -0.44311
#
#          44        45       46       47       48        49
# 0 -0.373840  1.015200 -0.24836  0.47535 -0.95568  0.114880
# 1  0.093191 -0.091906  0.40082 -0.90268  0.30191 -0.898620
# 2  0.007794 -0.015106 -0.28653 -0.16158 -0.35169 -0.825550
# 3  0.528470 -0.332560 -0.74839  1.21330 -0.64490 -0.713720
# 4  0.406760  0.427140 -0.25484  1.21220 -0.66438 -0.005737
#
# [5 rows x 53 columns]

# %%
data.columns = data.columns.astype(str)

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Train/test dataset splitting

# %%
# Train add validation set

import datetime
from datetime import date

data.Date = pd.to_datetime(data["Date"])

'''Defining train set'''

train = data.loc[data.Date < datetime.datetime(2015, 1, 2)]
X_train = train.loc[:, '0':'49'] # leaving out Label, Words, and Date
y_train = train.Label

'''Defining test set'''

test = data.loc[data.Date >= datetime.datetime(2015, 1, 2)]
X_test = test.loc[:, '0':'49'] # leaving out Label, Words, and Date
y_test = test.Label

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (484277, 50) (484277,)
# (119146, 50) (119146,)

# %% [markdown]
# ### Train and test models

# %%
import xgboost
from xgboost.sklearn import XGBClassifier
from sklearn.neural_network import MLPClassifier

# %%
models = ['RF','XGB', 'MLP']

def predModel(X_train, y_train, X_test, y_test, modelType=models, proba=False):
    
    if modelType == models[0]:
        rf = RandomForestClassifier(n_jobs=2, random_state=0)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)
        return(y_pred)
        
    elif modelType == models[1]:
        xg_boost = XGBClassifier(objective = 'binary:logistic')
        xg_boost.fit(X_train, y_train)
        y_pred = xg_boost.predict(X_test)
        if proba:
            y_pred = xg_boost.predict_proba(X_test)
        else:
            y_pred = xg_boost.predict(X_test)
        return(y_pred)
    
    elif modelType == models[2]:
        mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
        mlp.fit(X_train, y_train)
        y_pred = mlp.predict(X_test)
        if proba:
            y_pred = mlp.predict_proba(X_test)
        else:
            y_pred = mlp.predict(X_test)
        return(y_pred)

# %%
# Getting XGBoost label predictions
xgb_y_pred = predModel(X_train, y_train, X_test, y_test, modelType='XGB', proba=False)

# %%
# Getting MLP label predictions
mlp_y_pred = predModel(X_train, y_train, X_test, y_test, modelType='MLP', proba=False)

# %% [markdown]
# ### XGBoost

# %%
xgb_y_pred = pd.DataFrame([xgb_y_pred]).transpose()
xgb_y_pred.columns = xgb_y_pred.columns.astype(str)
xgb_y_pred = xgb_y_pred.rename(columns={'0': 'Preds_for_1'})
xgb_y_pred.head()
# Out:
#    Preds_for_1
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1

# %%
xgb_results = test[['Date', 'Words', 'Label']]
xgb_results.head()
# Out:
#              Date   Words  Label
# 494541 2015-01-02    case      1
# 494542 2015-01-02  cancer      1
# 494543 2015-01-02  result      1
# 494544 2015-01-02   sheer      1
# 494545 2015-01-02     bad      1

# %%
xgb_results['Preds'] = xgb_y_pred.values
xgb_results.head()
# Out:
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              Date   Words  Label  Preds
# 494541 2015-01-02    case      1      1
# 494542 2015-01-02  cancer      1      1
# 494543 2015-01-02  result      1      1
# 494544 2015-01-02   sheer      1      0
# 494545 2015-01-02     bad      1      1

# %%
# Grouping predictions back by date
# Computing the mean prediction by date ('majority vote')
xgb_check = xgb_results.groupby('Date').mean()
xgb_check.head()
# Out:
#             Label     Preds
# Date
# 2015-01-02    1.0  0.994505
# 2015-01-05    0.0  1.000000
# 2015-01-06    0.0  0.996466
# 2015-01-07    1.0  0.990937
# 2015-01-08    1.0  0.965870

# %%
# Preds now stands for mean predictions
# Determine the final label based on the mean predictions
xgb_check['Pred_label'] = xgb_check.apply(lambda row: 1 if row.Preds > 0.53 else 0, axis=1)
xgb_check.head()
# Out:
#             Label     Preds  Pred_label
# Date
# 2015-01-02    1.0  0.994505           1
# 2015-01-05    0.0  1.000000           1
# 2015-01-06    0.0  0.996466           1
# 2015-01-07    1.0  0.990937           1
# 2015-01-08    1.0  0.965870           1

# %%
xgb_check['Accuracy_per_pred'] = xgb_check.apply(lambda row: 1 if row.Label == row.Pred_label else 0, axis=1)
xgb_check.head()
# Out:
#             Label     Preds  Pred_label  Accuracy_per_pred
# Date
# 2015-01-02    1.0  0.994505           1                  1
# 2015-01-05    0.0  1.000000           1                  0
# 2015-01-06    0.0  0.996466           1                  0
# 2015-01-07    1.0  0.990937           1                  1
# 2015-01-08    1.0  0.965870           1                  1

# %%
accuracy_results = xgb_check['Accuracy_per_pred'].value_counts()
print('Correctly predicted (%): ', round(accuracy_results[1]/(accuracy_results[0]+accuracy_results[1]), 3)*100)
# Out:
# Correctly predicted (%):  50.8

# %% [markdown]
# ### MLP Classifier

# %%
mlp_y_pred = pd.Series(mlp_y_pred) 
mlp_y_pred = pd.DataFrame([mlp_y_pred]).transpose()
mlp_y_pred.columns = mlp_y_pred.columns.astype(str)
mlp_y_pred = mlp_y_pred.rename(columns={'0': 'Preds_for_1'})
mlp_y_pred.head()
# Out:
#    Preds_for_1
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
# Joining all columns
mlp_results = test[['Date', 'Words', 'Label']]
mlp_results.head()
# Out:
#              Date   Words  Label
# 494541 2015-01-02    case      1
# 494542 2015-01-02  cancer      1
# 494543 2015-01-02  result      1
# 494544 2015-01-02   sheer      1
# 494545 2015-01-02     bad      1

# %%
mlp_results['Preds'] = mlp_y_pred.values
mlp_results.head() # Preds = preds for 1
# Out:
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              Date   Words  Label  Preds
# 494541 2015-01-02    case      1      1
# 494542 2015-01-02  cancer      1      1
# 494543 2015-01-02  result      1      1
# 494544 2015-01-02   sheer      1      1
# 494545 2015-01-02     bad      1      1

# %%
mlp_check = mlp_results.groupby('Date').mean()
mlp_check.head()
# Out:
#             Label  Preds
# Date
# 2015-01-02      1      1
# 2015-01-05      0      1
# 2015-01-06      0      1
# 2015-01-07      1      1
# 2015-01-08      1      1

# %%
mlp_check['Pred_label'] = mlp_check.apply(lambda row: 1 if row.Preds > 0.53 else 0, axis=1)
mlp_check.head()
# Out:
#             Label  Preds  Pred_label
# Date
# 2015-01-02      1      1           1
# 2015-01-05      0      1           1
# 2015-01-06      0      1           1
# 2015-01-07      1      1           1
# 2015-01-08      1      1           1

# %%
mlp_check['Accuracy_per_pred'] = mlp_check.apply(lambda row: 1 if row.Label == row.Pred_label else 0, axis=1)
mlp_check.head()
# Out:
#             Label  Preds  Pred_label  Accuracy_per_pred
# Date
# 2015-01-02      1      1           1                  1
# 2015-01-05      0      1           1                  0
# 2015-01-06      0      1           1                  0
# 2015-01-07      1      1           1                  1
# 2015-01-08      1      1           1                  1

# %%
accuracy_results_mlp = mlp_check['Accuracy_per_pred'].value_counts()
print('Correctly predicted (%): ',
      round(accuracy_results_mlp[1]/(accuracy_results_mlp[0]+accuracy_results_mlp[1]), 3)*100)
# Out:
# Correctly predicted (%):  50.8

# %%
mlp_y_pred_probs = predModel(X_train, y_train, X_test, y_test, modelType='MLP', proba=True)
mlp_preds_for1 = [row[1] for row in mlp_y_pred_probs]
mlp_preds_for1_series = pd.Series(mlp_preds_for1) 
mlp_preds_for1_series.head()
# Out:
# 0    0.542140
# 1    0.541941
# 2    0.542140
# 3    0.541982
# 4    0.542140
# dtype: float64

# %%
mlp_preds_for1_series = pd.DataFrame([mlp_preds_for1_series]).transpose()
mlp_preds_for1_series.columns = mlp_preds_for1_series.columns.astype(str)
mlp_preds_for1_series = mlp_preds_for1_series.rename(columns={'0': 'Preds_for_1'})
mlp_preds_for1_series.head()
# Out:
#    Preds_for_1
# 0     0.542140
# 1     0.541941
# 2     0.542140
# 3     0.541982
# 4     0.542140

# %%
mlp_results['Precise_pred_probs'] = mlp_preds_for1_series.values
mlp_results.head()
# Out:
# /Users/dns/anaconda/envs/CS146/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              Date   Words  Label  Preds  Precise_pred_probs
# 494541 2015-01-02    case      1      1            0.542140
# 494542 2015-01-02  cancer      1      1            0.541941
# 494543 2015-01-02  result      1      1            0.542140
# 494544 2015-01-02   sheer      1      1            0.541982
# 494545 2015-01-02     bad      1      1            0.542140

# %%
mlp_check_probs = mlp_results.groupby('Date').mean()
mlp_check_probs.head()
# Out:
#             Label  Preds  Precise_pred_probs
# Date
# 2015-01-02      1      1            0.542100
# 2015-01-05      0      1            0.542102
# 2015-01-06      0      1            0.542083
# 2015-01-07      1      1            0.542091
# 2015-01-08      1      1            0.542092

# %%
# checking the % of 1s in the original set
y_train.value_counts()[1]/(y_train.value_counts()[1]+y_train.value_counts()[0])
# Out:
# 0.5420823206553275

# %% [markdown]
# ### References

# %% [markdown]
# Alexander, 2017. In Stack Overflow. Retrieved from: https://stackoverflow.com/questions/32468402/how-to-explode-a-list-inside-a-dataframe-cell-into-separate-rows?fbclid=IwAR3cUJb9ZuaprvbZ1ShQcHbPZNElmJZVZBktbVdM3I19Kw5KmXbtKKT48U8
